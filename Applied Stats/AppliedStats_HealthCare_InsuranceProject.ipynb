# %%
print("******************************Task1: Import the necessary libraries***********************************************************")
print("\n Importing numpy, pandas, seaborn, matplotlib,scipy.stats, math")
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import kurtosis, skew, stats
from math import sqrt
# %matplotlib inline
print('\n******************************Task1: Necessary Librabries Imported************************************************************')
# Out:
# ******************************Task1: Import the necessary libraries***********************************************************
#
#  Importing numpy, pandas, seaborn, matplotlib,scipy.stats, math
#
# ******************************Task1: Necessary Librabries Imported************************************************************

# %%
print("***********************************Task2: Read the data as a data frame************************************************")

insurance=pd.read_csv("insurance.csv")
print("First 5 rows of Insurance data frame are as follows: \n" )
print(format(insurance.head()))
print("\n \nNote*: To see more data, either put value to head function or print insurance dataframe directly by using: \n \nprint(format(insurance)")
print("***********************************Task2: Reading data as data frame Completed*******************************************")
# Out:
# ***********************************Task2: Read the data as a data frame************************************************
# First 5 rows of Insurance data frame are as follows:
#
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#
# Note*: To see more data, either put value to head function or print insurance dataframe directly by using:
#
# print(format(insurance)
# ***********************************Task2: Reading data as data frame Completed*******************************************

# %%
print("*************Task 3: Perform basic EDA which should include the following and print out your insights at every step.***********")
# Out:
# *************Task 3: Perform basic EDA which should include the following and print out your insights at every step.***********

# %%
print("-------------------------------------------Task3.a: Shape of the data--------------------------------------------------")

print ("\nShape of data is: " + format(insurance.shape))

print("\n-------------------------------------------Task3.a: Complete--------------------------------------------------")
# Out:
# -------------------------------------------Task3.a: Shape of the data--------------------------------------------------
#
# Shape of data is: (1338, 7)
#
# -------------------------------------------Task3.a: Complete--------------------------------------------------

# %%
print("-------------------------------------------Task3.b: Data type of each attribute-----------------------------------------")

print ("\nDataTypes of each attributes are : \n" + format(insurance.dtypes))

print("\n-------------------------------------------Task3.b: Complete-----------------------------------------")
# Out:
# -------------------------------------------Task3.b: Data type of each attribute-----------------------------------------
#
# DataTypes of each attributes are :
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
#
# -------------------------------------------Task3.b: Complete-----------------------------------------

# %%
print("----------------------------------Task3.c: Checking the presence of missing values-------------------------------------")

print("\nFollowing is the count of missing values per column: \n" +format(insurance.isnull().sum()))

print("\n----------------------------------Task3.c: Complete-------------------------------------")
# Out:
# ----------------------------------Task3.c: Checking the presence of missing values-------------------------------------
#
# Following is the count of missing values per column:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64
#
# ----------------------------------Task3.c: Complete-------------------------------------

# %%
print("---------------------------------Task3.d. 5 point summary of numerical attributes-------------------------------------")

print("\nFollowing is the five point summary for the given data: \n" + format(insurance.describe()))
print("\n---------------------------------Task3.d. Complete-------------------------------------")
# Out:
# ---------------------------------Task3.d. 5 point summary of numerical attributes-------------------------------------
#
# Following is the five point summary for the given data:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010
#
# ---------------------------------Task3.d. Complete-------------------------------------

# %%
print("------------------------------------Task3.e Distribution of ‘bmi’, ‘age’ and ‘charges’ columns.--------------------------")

sns.pairplot(insurance[['bmi','age','charges']])
# Out:
# ------------------------------------Task3.e Distribution of ‘bmi’, ‘age’ and ‘charges’ columns.--------------------------

# %%
print("Plot the Distribution of 'bmi' column, it follows Normal distribution")
sns.distplot(insurance['bmi'])
# Out:
# Plot the Distribution of 'bmi' column, it follows Normal distribution

# %%
print("Plot the Distribution of 'age' column")
sns.distplot(insurance['age'])
# Out:
# Plot the Distribution of 'age' column

# %%
print("Plot the Distribution of 'charges' column")
sns.distplot(insurance['charges'])
# Out:
# Plot the Distribution of 'charges' column

# %%
print("\n----------------------------------Task3.e Complete------------------------------------------------------------------------")
# Out:
# ----------------------------------Task3.e Complete------------------------------------------------------------------------

# %%
print("--------------------------------Task3.f Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns-----------------------")

print('Skewness \n' +format(insurance.skew(axis = 0, skipna = True ) ))

print("\nWhere\nskewness = 0 : normally distributed\n\nskewness > 0 : right skewed\n\nskewness < 0 : left skewed")

print("--------------------------------Task3.f Complete-----------------------------------------------------------------------")
# Out:
# --------------------------------Task3.f Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns-----------------------
# Skewness
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64
#
# Where
# skewness = 0 : normally distributed
#
# skewness > 0 : right skewed
#
# skewness < 0 : left skewed
# --------------------------------Task3.f Complete-----------------------------------------------------------------------

# %%
print("-------------------------------Task3.g Checking the presence of outliers in ‘bmi’, ‘age’ and‘charges' columns---------------")

print('\n\nOutliers for bmi column\n')

sns.boxplot(insurance['bmi'])
# Out:
# -------------------------------Task3.g Checking the presence of outliers in ‘bmi’, ‘age’ and‘charges' columns---------------
#
#
# Outliers for bmi column

# %%
print('\n\nOutliers for age column\n')

sns.boxplot(insurance['age'])
# Out:
# Outliers for age column

# %%
print('\n\nOutliers for charges column\n')

sns.boxplot(insurance['charges'])
# Out:
# Outliers for charges column

# %%
print("There are outliers in bmi & charges columns. While there are no outliers in age column.")
print("\n-------------------------------Task3.g Complete---------------------------------------------------------------------------")
# Out:
# There are outliers in bmi & charges columns. While there are no outliers in age column.
#
# -------------------------------Task3.g Complete---------------------------------------------------------------------------

# %%
print("-----------------------------------Task3.h Distribution of categorical columns (include children)----------------------------")

#Converting all object types varibles to type category
print("All datatypes of original data\n "+ format(insurance.dtypes))
inc = insurance.copy()

inc[inc.select_dtypes(['object']).columns] = inc.select_dtypes(['object']).apply(lambda x: x.astype('category'))

print("\nConverted datatypes of data frame inc\n "+ format(inc.dtypes))

col = list(inc.select_dtypes(include=["category"]))
inc = inc.sort_values('children')

print('\nCategorical Columns are : \n' + format(col))
print("\nCategorical distribution is: \n")

#Plotting all categorical Column

sns.catplot(x = 'region', y = 'children', data = inc, hue = 'sex', kind = 'violin', col = 'smoker')
# Out:
# -----------------------------------Task3.h Distribution of categorical columns (include children)----------------------------
# All datatypes of original data
#  age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
#
# Converted datatypes of data frame inc
#  age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object
#
# Categorical Columns are :
# ['sex', 'smoker', 'region']
#
# Categorical distribution is:

# %%
print("-----------------------------------Task3.h Complete------------------------------------------------------------------")
# Out:
# -----------------------------------Task3.h Complete------------------------------------------------------------------

# %%
print("--------------------------------Task 3.i Pair plot that includes all the columns of the dataframe----------------------")

a=sns.pairplot(insurance,hue = 'region',)
a.fig.suptitle("Pair plots with hue as region\n")  
b=sns.pairplot(insurance,hue = 'sex')
b.fig.suptitle("Pair plots with hue as sex\n\n\n\n")
c=sns.pairplot(insurance,hue = 'smoker')
c.fig.suptitle("Pair plots with hue as smoker\n\n\n\n")
# Out:
# --------------------------------Task 3.i Pair plot that includes all the columns of the dataframe----------------------
# Text(0.5, 0.98, 'Pair plots with hue as smoker\n\n\n\n')

# %%
print("--------------------------------Task 3.i Complete-------------------------------------------------------------")
# Out:
# --------------------------------Task 3.i Complete-------------------------------------------------------------

# %%
print("************************************Task 3 has been Completed***************************************************")
# Out:
# ************************************Task 3 has been Completed***************************************************

# %%
print("************************************Task 4: Answer the following questions with statistical evidence***************************")
# Out:
# ************************************Task 4: Answer the following questions with statistical evidence***************************

# %%
print("-------------------------------Task 4.a. Do charges of people who smoke differ significantly from the people who don't?----------")
print("\n#Null Hypothesis--> H0 = charges has no effect on smoking#")
print("#Alternate hypothesis--> H1 = charges has effect on smoking")

x = np.array(insurance[insurance['smoker'] == 'yes']['charges'])#selecting charges values corresponding to smoker as an array
y = np.array(insurance[insurance['smoker'] == 'no']['charges'])#selecting charges values corresponding to not smoker as an array
t,p_value = stats.ttest_ind(x,y,axis =0)#performing an independent T-test
print("\nP value is : " + format(np.round(p_value)))
if p_value <0.05:
    print("\nAs p_value is less than 0.05, charges has effect on smoking(reject H0)")
else:
    print("\nAs p_value is greater than 0.05, charges has no effect on smoking(accept H0)")

print("\n---------------- ---------------Task 4.a. Complete------------------------------------------------------------------------------")
# Out:
# -------------------------------Task 4.a. Do charges of people who smoke differ significantly from the people who don't?----------
#
# #Null Hypothesis--> H0 = charges has no effect on smoking#
# #Alternate hypothesis--> H1 = charges has effect on smoking
#
# P value is : 0.0
#
# As p_value is less than 0.05, charges has effect on smoking(reject H0)
#
# ---------------- ---------------Task 4.a. Complete------------------------------------------------------------------------------

# %%
print("------------------------------------Task 4.b: Does bmi of males differ significantly from that of females?--------------------")
print("\n#Null Hypothesis--> H0 = bmi has no effect on gender")
print("#Alternate hypothesis--> H1 = bmi has effect on gender")

x = np.array(insurance[insurance['sex'] == 'male']['bmi'])#selecting bmi values corresponding to male as an array
y = np.array(insurance[insurance['sex'] == 'female']['bmi'])#selecting bmi values corresponding to female as an array
t,p_value = stats.ttest_ind(x,y,axis =0)#performing an independent T-test
print("P value is :")
print(np.round(p_value))

if p_value <0.05:
    print("\nAs p_value is less than 0.05,bmi has effect on gender(reject H0)")
else:
    print("\nbmi has no effect on gender(accept H0)")

    
print("\n------------------------------------Task 4.b: Complete-------------------------------------------------------------------")
# Out:
# ------------------------------------Task 4.b: Does bmi of males differ significantly from that of females?--------------------
#
# #Null Hypothesis--> H0 = bmi has no effect on gender
# #Alternate hypothesis--> H1 = bmi has effect on gender
# P value is :
# 0.0
#
# bmi has no effect on gender(accept H0)
#
# ------------------------------------Task 4.b: Complete-------------------------------------------------------------------

# %%
print("--------------------------Task 4.c : Is the proportion of smokers significantly different in different genders?----------------")
print("\ncrosstab for smoker and sex:\n\n" +format(pd.crosstab(insurance['smoker'],insurance['sex'])))
# Out:
# --------------------------Task 4.c : Is the proportion of smokers significantly different in different genders?----------------
#
# crosstab for smoker and sex:
#
# sex     female  male
# smoker
# no         547   517
# yes        115   159

# %%
print("#Null Hypothesis--> H0 = there is no difference in proportion of smokers in different genders")
print("#Alternate hypothesis--> H1 = there is difference in proportion of smokers in different genders" )

# so from above we can see that 547 females are not smoker and 115 females are smoker
#like wise 517 males are not smoker and 159 males are smoker

#E11= expected value of smoker=no and sex=female
#E12 = expected value of smoker=no and sex= male
#E21 = expected value of smoker=yes and sex= female
#E22 = expected value of smoker=yes and sex= male

E11 = 1064*(662/1338)
print("expected value of smoker=no and sex=female is {}".format(E11))
E12 = 1064*(676/1338)
print("expected value of smoker=no and sex= male is {}".format(E12))
E21 = 274*(662/1338)
print("expected value of smoker=yes and sex= female is {}".format(E21))
E22 = 274*(676/1338)
print("expected value of smoker=yes and sex= male is {}".format(E22))

#chi-square = summation((observed-expected)^2/expected)
chiE11 = np.square(547-E11)/E11
print("chiE11 is {}".format(chiE11))
chiE12 = np.square(517-E12)/E12
print("chiE12 is {}".format(chiE12))
chiE21 = np.square(115-E21)/E21
print("chiE21 is {}".format(chiE21))
chiE22 = np.square(159-E22)/E22
print("chiE22 is {}".format(chiE22))

chisquare = chiE11+chiE12+chiE21+chiE22
print("chi-square is {}".format(chisquare))

degree_of_freedom = (2-1)*(2-1)
print("degree of freedom is {}".format(degree_of_freedom))

#having calculated the chi square value and degree of freedom ,we consult a chi-square
#table to check whether the chi square statistics of 7.76 exceeds the critical value
#of the chi square distribution, The critical value for alpha of 0.05(95% confidence) is 3.84
#since the statistics is much larger than 3.84, we have sufficient evidence to reject the H0(null hypothesis)

if chisquare<3.84:
    print("there is no difference in proportion of smokers in different genders(accept H0)")
else:
    print("there is difference in proportion of smokers in different genders(reject H0)")
    
print("\n--------------------------Task 4.c : Complete-------------------------------------------------------------------")
# Out:
# #Null Hypothesis--> H0 = there is no difference in proportion of smokers in different genders
# #Alternate hypothesis--> H1 = there is difference in proportion of smokers in different genders
# expected value of smoker=no and sex=female is 526.4334828101644
# expected value of smoker=no and sex= male is 537.5665171898356
# expected value of smoker=yes and sex= female is 135.56651718983557
# expected value of smoker=yes and sex= male is 138.43348281016443
# chiE11 is 0.8034854224352866
# chiE12 is 0.7868451917931356
# chiE21 is 3.120103976172045
# chiE22 is 3.0554864382039844
# chi-square is 7.765921028604452
# degree of freedom is 1
# there is difference in proportion of smokers in different genders(reject H0)
#
# --------------------------Task 4.c : Complete-------------------------------------------------------------------

# %%
print("------------Task 4.d. Is the distribution of bmi across women with no children, one child and two children, the same ?---------")

#make the data frame of females having children less than or equal to 2


bmidata = insurance[(insurance['children'] <= 2) & (insurance['sex'] == 'female')][['sex','bmi', 'children']]
print("\n\nData frame of females having children less than or equal to 2 \n"+ format(bmidata.head()))
# Out:
# ------------Task 4.d. Is the distribution of bmi across women with no children, one child and two children, the same ?---------
#
#
# Data frame of females having children less than or equal to 2
#        sex    bmi  children
# 0   female  27.90         0
# 5   female  25.74         0
# 6   female  33.44         1
# 9   female  25.84         0
# 11  female  26.29         0

# %%
#Grouping into 3 groups, 0,1,2 children
zero_ch = np.array(bmidata[bmidata['children'] == 0]['bmi'])
one_ch = np.array(bmidata[bmidata['children'] == 1]['bmi'])
two_ch = np.array(bmidata[bmidata['children'] == 2]['bmi'])
a=np.mean(zero_ch)
print("Mean of bmi when woman has 0 children: " + format(np.round(a)))
b=np.mean(one_ch)
print("Mean of bmi when woman has 1 child: " + format(np.round(b)))
c=np.mean(two_ch)
print("Mean of bmi when woman has 2 children: " + format(np.round(c)))
# Out:
# Mean of bmi when woman has 0 children: 30.0
# Mean of bmi when woman has 1 child: 30.0
# Mean of bmi when woman has 2 children: 31.0

# %%
print("Means in all three cases is almost equal. Hence the distribution of bmi across women with no children,one child and two children is same")
# Out:
# Means in all three cases is almost equal. Hence the distribution of bmi across women with no children,one child and two children is same

# %%
print("\nTo prove Graphically")
#Relationship between Bmi and children for women
bmigraph = sns.jointplot(bmidata['bmi'],bmidata['children'])
bmigraph = bmigraph.annotate(stats.pearsonr, fontsize=10, loc=(0.2, 0.8))
# Out:
# To prove Graphically
# C:\Users\abhole\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
sns.boxplot(x = 'children', y = 'bmi', data = bmidata)

# %%
print("From both the above graph we can derive BMI distribution for women with 0,1,2 children are same.")
print("----------------------------------------Task 4.d Complete----------------------------------------------------------------")
# Out:
# From both the above graph we can derive BMI distribution for women with 0,1,2 children are same.
# ----------------------------------------Task 4.d Complete----------------------------------------------------------------

# %%
print("----------------------------------------Task 4 Complete----------------------------------------------------------------")
# Out:
# ----------------------------------------Task 4 Complete----------------------------------------------------------------
